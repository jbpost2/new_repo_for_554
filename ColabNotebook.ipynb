# %% [markdown]
# <a href="https://colab.research.google.com/github/jbpost2/new_repo_for_554/blob/main/ColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3+5
# Out:
# 8

# %%
1+3
# Out:
# 4
